# %%
import pandas as pd

# %%
df=pd.read_csv("queryResults(Archief)_v2.csv", sep=';')

# %%
df_erchief.columns=['title','description']

# %%
df_DMG=pd.read_csv("DMG.csv", sep=';')

# %%
df_DMG.columns=['title','description']

# %%
df_DMG
# Out:
#                                                   title  \
# 0                                            "Sorrento"
# 1                      "Schrijfkist met passietafereel"
# 2                                  "Vaas 53 met dahlia"
# 3           "Mokkakop van het servies 'How Much White'"
# 4                               "Lijster op lijsterbes"
# ...                                                 ...
# 1001                                         "Siervaas"
# 1002                           "Paar vazen 93 Violetta"
# 1003                          "Vaasje met bosviooltjes"
# 1004                                      "Vaas Créquy"
# 1005   "Oranje-groene vaas met hoofd van blazende ou...
#
#                                             description
# 0     "Het patroon van deze lap gordijnstof vertoont...
# 1     "Deze schrijfkist of 'schrijflaey' met ijzeren...
# 2     "Aardewerken vaas modelnummer 53, polychroom g...
# 3     "Het witte porseleinen servies ‘How Much White...
# ...

# %%
df_industriemusium=pd.read_csv("industriemusium.csv", sep=';')

# %%
df_industriemusium.columns=['title','description']

# %%
df_industriemusium
# Out:
#                                            title  \
# 0           "Jigger of verfmachine voor textiel"
# 1         "Gland of kwast met vorm, keel en rok"
# 2               "Slagmachine van het merk Platt"
# 3    "Vlakke embrasse om gordijn open te houden"
# 4     "Gland of kwast met 4 vormen, keel en rok"
# ..                                           ...
# 947             "Houten mal of vorm voor hoeden"
# 948             "Houten mal of vorm voor hoeden"
# 949             "Houten mal of vorm voor hoeden"
# 950             "Houten mal of vorm voor hoeden"
# 951             "Houten mal of vorm voor hoeden"
#
#                                            description
# 0    "Rond 1904-1905 ontwikkelt Carl Gruschwitz uit...
# 1    "Kwast bestaande uit kabel, turkse knoop, char...
# 2    "Slagmachine van de Engelse fabrikant Platt Br...
# 3    "Embrasse crête en forme. Uiteinden met lus. K...
# 4    "Kwast bestaande uit korte kabel, bol gerold m...
# ...
